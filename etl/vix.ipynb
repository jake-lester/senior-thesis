# %%
import numpy as np
import pandas as pd
import os
import math

# %% [markdown]
# # Load into dataframes

# %%
def getFilepath(fn):
    """ gets filepath for file in data folder"""
    cwd_list = os.getcwd().split('\\')
    fp = '\\'.join(cwd_list[:-1] + ['data', fn])
    return  os.path.normpath(fp)

# %%
def loadVixCurrent(fn='vixcurrent.csv'):
    fp = getFilepath(fn)
    df = pd.read_csv(fp, header=1)
    return df

# %%
def cleanVixCurrent(df):
    return df.drop(labels = ["VIX Open", "VIX High", "VIX Low"],
                  axis = 'columns')

# %%
def makeVixCurrent():
    return cleanVixCurrent(loadVixCurrent())

# %% [markdown]
# # date conversion
# m/dd/YYYY -> YYYY-mm-dd

# %%
# Useful for making dates in twitter query format

def vixCurrent_date2twitter_format(date):
    """ "m/dd/YYYY' -> 'YYYY-mm-dd' """
    date = date.split("/")
    for i in range(2):
        if len(date[i]) == 1:
            date[i] = '0'+date[i]
    date = date[2] + '-' + date[0] + '-' + date[1]
    return date

def update_date_column(df):
    new_index = [vixCurrent_date2twitter_format(x) for x in df.loc[:,'Date']]
    df.loc[:,'Date'] = new_index
    return df

def filter_df_byDate(df, start=False, end=False):
    '''start='YYYY-MM-DD' '''
    assert start != end
    #assert format of start,end
    if start and end:
        df.query("Date >= "+start+" & Date <= "+end+" ", inplace=True)
    elif start:
        df.query("Date >= "+start, inplace=True)
    elif end:
        df.query("Date <= "+end, inplace=True)

# %%
#vix_df_small.head()

# %% [markdown]
# # make price changes column

# %%
def update_df_priceChange(df):
    x0 = df.loc[:len(df)-2]['VIX Close'].values
    x1 = df.loc[1:]['VIX Close'].values
    delta = np.divide(np.subtract(x1,x0), x0)
    delta = [np.nan] + list(delta)
    df.insert(2, "Daily Price Change", delta)
    df = df.drop(0)
    return df.reset_index(drop=True)

# %% [markdown]
# # Which to include

# %%
def update_df_inclusion(df, n):
    ''' n : how many to use'''
    df.sort_values(by=['Daily Price Change'], inplace=True)
    include = np.zeros(len(df))
    include[:math.floor(n/3)] = 1
    include[len(df) - math.floor(n/3):] = 1
    include[math.floor(len(df)/2 - n/6):math.floor(len(df)/2 + n/6)] = 1
    df.insert(3, "Include", include)
    return df.sort_index()

# %% [markdown]
# ## Run and display

# %%
##
vix_df_all = makeVixCurrent()
vix_df_all = update_date_column(vix_df_all)
vix_df_all = update_df_priceChange(vix_df_all)
vix_df_all = update_df_inclusion(vix_df_all, 100)
filter_df_byDate(vix_df_all, start="'2008-01-01'")
vix_df_all[vix_df_all['Include'] == 1].reset_index(drop=True)
# Out:
#           Date  VIX Close  Daily Price Change  Include
# 0   2008-01-07      23.79           -0.006266      1.0
# 1   2008-03-18      25.79           -0.200062      1.0
# 2   2008-09-11      24.39           -0.005302      1.0
# 3   2008-09-29      46.72            0.344847      1.0
# 4   2008-10-13      54.99           -0.213867      1.0
# 5   2008-10-20      52.97           -0.246836      1.0
# 6   2008-10-22      69.65            0.311429      1.0
# 7   2009-01-21      46.42           -0.180583      1.0
# 8   2009-04-02      42.04           -0.005676      1.0
# 9   2009-10-14      22.86           -0.005655      1.0
# 10  2010-01-07      19.06           -0.005219      1.0
# 11  2010-03-04      18.72           -0.005842      1.0
# 12  2010-03-22      16.87           -0.005893      1.0
# 13  2010-04-27      22.81            0.305667      1.0
# 14  2010-05-06      32.80            0.316740      1.0
# 15  2010-05-10      28.84           -0.295726      1.0
# 16  2010-05-20      45.79            0.296433      1.0
# 17  2010-06-23      26.91           -0.005176      1.0
# 18  2010-08-16      26.10           -0.005335      1.0
# 19  2011-02-22      20.80            0.265977      1.0
# 20  2011-07-20      19.09           -0.006247      1.0
# 21  2011-08-04      31.66            0.354149      1.0
# 22  2011-08-08      48.00            0.500000      1.0
# 23  2011-08-09      35.06           -0.269583      1.0
# 24  2011-08-18      42.67            0.351172      1.0
# 25  2011-11-09      36.16            0.315866      1.0
# 26  2012-02-07      17.65           -0.006194      1.0
# 27  2012-12-31      18.02           -0.206866      1.0
# 28  2013-01-02      14.68           -0.185350      1.0
# 29  2013-02-11      12.94           -0.006144      1.0
# ..         ...        ...                 ...      ...
# 49  2016-06-23      17.25           -0.185168      1.0
# 50  2016-06-24      25.76            0.493333      1.0
# 51  2016-06-28      18.75           -0.213836      1.0
# 52  2016-09-09      17.50            0.398881      1.0
# 53  2016-11-09      14.38           -0.232657      1.0
# 54  2017-01-10      11.49           -0.006055      1.0
# 55  2017-04-24      10.84           -0.259057      1.0
# 56  2017-05-17      15.59            0.463850      1.0
# 57  2017-05-19      12.04           -0.178718      1.0
# 58  2017-06-07      10.39           -0.005742      1.0
# 59  2017-08-10      16.04            0.443744      1.0
# 60  2017-08-14      12.33           -0.205029      1.0
# 61  2017-08-17      15.55            0.324532      1.0
# 62  2017-09-14      10.44           -0.005714      1.0
# 63  2018-02-01      13.47           -0.005170      1.0
# 64  2018-02-02      17.31            0.285078      1.0
# 65  2018-02-05      37.32            1.155979      1.0
# 66  2018-02-06      29.98           -0.196677      1.0
# 67  2018-02-14      19.26           -0.228674      1.0
# 68  2018-03-22      23.34            0.306831      1.0
# 69  2018-05-29      17.02            0.287443      1.0
# 70  2018-09-12      13.14           -0.006051      1.0
# 71  2018-10-10      22.96            0.439498      1.0
# 72  2018-10-16      17.62           -0.172770      1.0
# 73  2018-11-07      16.36           -0.178302      1.0
# 74  2019-05-13      20.55            0.281172      1.0
# 75  2019-06-13      15.82           -0.005657      1.0
# 76  2019-08-05      24.59            0.396366      1.0
# 77  2019-08-06      20.17           -0.179748      1.0
# 78  2019-08-13      17.52           -0.169275      1.0
#
# [79 rows x 4 columns]
