# %%
import database.fetch as fetch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import common.dates as dates
import load

# %%
def plot_finance(index_df, title, group="1440T"):
    #import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.ticker as ticker
    import common.dates as dates
    # adapted from matplotlib tutorial
    def format_date(x, pos=None):
        thisind = np.clip(int(x + 0.5), 0, N - 1)
        return date[thisind].strftime('%Y-%m-%d')
    
    index_df =  dates.group_data(index_df, ['close'], method='lastValue', group=group)
    index_df = index_df.set_index('datetime', drop=False)
    index_df = index_df[index_df['datetime'].notnull()]

    fig, ax = plt.subplots(ncols=1, figsize=(8, 4))
    
    
    date = index_df['datetime'].astype('O')
    N = len(index_df)
    ind = np.arange(N)  # the evenly spaced plot indices
    ax.plot(ind, index_df['close'])
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(format_date))
    ax.set_title(title + " (Group=" + group[:-1]+"minutes)"+" (npoints= " + str(len(index_df)) + ")")#"VIX Close Price from 2020-03-02 to 2020-04-07")
    ax.set_xlabel("Date")
    ax.set_ylabel("Close Price")
    fig.autofmt_xdate()
    
    #ax.set_title("SPX Close Price from 2020-03-02 to 2020-04-07")

    plt.show()

# %%
def plot_finance2(index_df, title, group='1440T'):
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.ticker as ticker
    import common.dates as dates
    
    # adapted from matplotlib tutorial
    def format_date(x, pos=None):
        thisind = np.clip(int(x + 0.5), 0, N - 1)
        return date[thisind].strftime('%Y-%m-%d')
    

    
    index_df = dates.group_data(index_df, ['close'], method='lastValue', group=group)
    index_df = index_df.set_index('datetime', drop=False)
    #remove NaT values
    index_df = index_df[index_df['datetime'].notnull()]

    fig, ax = plt.subplots(ncols=1, figsize=(8, 4))
    
    
    date = index_df['datetime'].astype('O')
    index_df['close'] = index_df['close'].pct_change()
    index_df = index_df.dropna()
    N = len(index_df)
    ind = np.arange(N)  # the evenly spaced plot indices
    ax.plot(ind, index_df['close'])
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(format_date))
    ax.set_title(title + " (Group=" + group[:-1]+"minutes)"+" (npoints= " + str(len(index_df)) + ")")
    ax.set_xlabel("Date")
    ax.set_ylabel("Close Price Pct Change")
    fig.autofmt_xdate()
    
    plt.show()

# %%
def plot_finance2(index_df, title, group='1440T'):
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.ticker as ticker
    import common.dates as dates
    
    # adapted from matplotlib tutorial
    def format_date(x, pos=None):
        thisind = np.clip(int(x + 0.5), 0, N - 1)
        return date[thisind].strftime('%Y-%m-%d')
    

    
    index_df = dates.group_data(index_df, ['close'], method='lastValue', group=group)
    index_df = index_df.set_index('datetime', drop=False)
    #remove NaT values
    index_df = index_df[index_df['datetime'].notnull()]

    fig, ax = plt.subplots(ncols=1, figsize=(8, 4))
    
    
    date = index_df['datetime'].astype('O')
    index_df['close'] = index_df['close'].pct_change().dropna
    N = len(index_df)
    ind = np.arange(N)  # the evenly spaced plot indices
    ax.plot(ind, index_df['close'])
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(format_date))
    ax.set_title(title + " (Group=" + group[:-1]+"minutes)"+" (npoints= " + str(len(index_df)) + ")")
    print(index_df.head())
    ax.set_xlabel("Date")
    ax.set_ylabel("Close Price Pct Change")
    fig.autofmt_xdate()
    
    plt.show()

# %% [markdown]
# # VIX Close prive vs Time plot

# %%
# VIX Close Price from 2020-03-02 to 2020-04-07 (group=60T)
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(vix_df, title, "60T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(vix_df, title, "180T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(vix_df, title, "360T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(vix_df, title, "720T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(vix_df, title, "1440T")

# %% [markdown]
# # SPX Close prive vs Time plot

# %%
# SPX Close Price from 2020-03-02 to 2020-04-07 (group=60T)
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(spx_df, title, "60T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(spx_df, title, "180T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(spx_df, title,  "360T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(spx_df, title, "720T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price from 2020-03-02 to 2020-04-07"
plot_finance(spx_df, title, "1440T")

# %% [markdown]
# # VIX Close price pct Change vs Time plot

# %%
# VIX Close Price from 2020-03-02 to 2020-04-07 (group=60T)
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(vix_df, title, "60T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(vix_df, title, "180T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(vix_df, title, "360T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(vix_df, title, "720T")

# %%
import database.fetch as fetch
vix_df = fetch.fetch_vix()
title = "VIX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(vix_df, title, "1440T")

# %% [markdown]
# # SPX Close prive vs Time plot

# %%
# SPX Close Price from 2020-03-02 to 2020-04-07 (group=60T)
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(spx_df, title, "60T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(spx_df, title, "180T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(spx_df, title, "360T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(spx_df, title, "720T")

# %%
import database.fetch as fetch
spx_df = fetch.fetch_spx()
title = "SPX Close Price Pct Change from 2020-03-02 to 2020-04-07"
plot_finance2(spx_df, title, "1440T")
